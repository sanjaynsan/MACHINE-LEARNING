# %%
#import all the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#pd is a class in which the function read_csv calls the excel
data = pd.read_csv('insurance_pre.csv')

# %%
#display the data
data.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
#Removing categorical data
data=pd.get_dummies(data,drop_first=True)

# %%
#refering the output and input to the variables independent and dependent
independent = data[["age","bmi","children","sex_male","smoker_yes"]]
dependent = data[['charges']]

# %%
#call traintest split fuction,assign the xtrain xtest ytrain ytest
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent,dependent,test_size = 1/3,random_state = 0)

# %%
#standarization or reparametrization for train set.this is makes the svm to pplot the points efficiently
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
#model creation calls LinearRegression fuction
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit=True,verbose = 3,n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# C:\Users\sanjaykumar\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.1s finished
# C:\Users\sanjaykumar\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\sanjaykumar\anaconda3\envs\AI\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#find y_pred using regressor.predict()
re=grid.cv_results_
grid_predictions = grid.predict(x_test)

# %%
#find r2score using r2_score()
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
#display r2 score
r_score
# Out:
# 0.8577898390283567

# %%
print("The r_square value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The r_square value for the best parameter{'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}: 0.8577898390283567

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.029256      0.002049         0.008643    9.395939e-04      10
# 1        0.022939      0.001629         0.006982    8.485379e-07      10
# 2        0.033911      0.002937         0.012964    2.935230e-03      10
# 3        0.024599      0.002858         0.006983    2.156743e-03      10
# 4        0.039560      0.002618         0.011300    1.878963e-03      10
# 5        0.022938      0.002934         0.006316    9.402682e-04      10
# 6        0.027926      0.000001         0.007645    4.688416e-04      10
# 7        0.018285      0.000939         0.004326    4.750248e-04      10
# 8        0.024932      0.003258         0.006982    8.144908e-04     100
# 9        0.020279      0.002049         0.005319    4.701911e-04     100
# 10       0.033577      0.000470         0.007979    8.152696e-04     100
# 11       0.028258      0.004099         0.004655    4.707545e-04     100
# 12       0.027260      0.002619         0.006982    8.160487e-04     100
# 13       0.018615      0.000938         0.005322    4.709782e-04     100
# 14       0.027925      0.001411         0.009973    8.144911e-04     100
# 15       0.026595      0.001697         0.004654    4.696312e-04     100
# 16       0.037567      0.001244         0.007645    4.708651e-04    1000
# 17       0.048870      0.009906         0.005652    4.704713e-04    1000
# 18       0.041554      0.002488         0.008312    4.706399e-04    1000
# 19       0.052522      0.008478         0.003990    5.619580e-07    1000
# 20       0.043877      0.001419         0.006981    1.184119e-06    1000
# 21       0.037899      0.002936         0.005984    8.139069e-04    1000
# 22       0.042885      0.002444         0.008644    4.695727e-04    1000
# 23       0.046875      0.010203         0.004322    4.705274e-04    1000
# 24       0.042220      0.004017         0.007314    4.696284e-04    2000
# 25       0.062167      0.003672         0.005652    4.698532e-04    2000
# 26       0.034242      0.004485         0.007979    1.123916e-07    2000
# 27       0.096076      0.066087         0.004654    4.699655e-04    2000
# 28       0.043550      0.006003         0.007314    4.705840e-04    2000
# 29       0.064826      0.010772         0.004655    4.706962e-04    2000
# 30       0.031915      0.002936         0.008311    4.699093e-04    2000
# 31       0.101063      0.056196         0.004322    4.699093e-04    2000
# 32       0.052859      0.002936         0.007647    9.398185e-04    3000
# 33       0.125332      0.039562         0.003657    9.399872e-04    3000
# 34       0.031249      0.003390         0.008644    4.704713e-04    3000
# 35       0.076794      0.039526         0.004987    1.628787e-03    3000
# 36       0.046211      0.003084         0.007313    9.397069e-04    3000
# 37       0.131981      0.058168         0.004322    9.398747e-04    3000
# 38       0.034574      0.002860         0.008313    1.243434e-03    3000
# 39       0.064494      0.020085         0.003657    1.244049e-03    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.029133
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.076672
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.079325
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.429231
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.029317
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.073471
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.078551
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.429231
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.321370
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.548034
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.531784
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.635759
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.322808
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.535827
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.529281
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.635759
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.741114
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.811859
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.376414
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.709931
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.741508
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.810406
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.383460
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.709931
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.808850
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822528
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.054850
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.709784
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.809156
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822617
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.011309
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.709784
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.816813
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.822318
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.956222
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.709612
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.817102
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.821997
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.868954
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.709612
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.129874          -0.116121        -0.072174        0.071974
# 1           -0.075966          -0.064307        -0.021091        0.069408
# 2           -0.093756          -0.075898        -0.029987        0.077767
# 3            0.216643           0.223417         0.289920        0.098712
# 4           -0.129978          -0.116230        -0.072183        0.072111
# 5           -0.074221          -0.062481        -0.020971        0.067064
# 6           -0.093412          -0.075585        -0.030027        0.077248
# 7            0.216643           0.223417         0.289920        0.098712
# 8            0.110819           0.106686         0.179784        0.100299
# 9            0.409799           0.393006         0.450389        0.069500
# 10           0.389102           0.392744         0.437982        0.066456
# 11           0.554602           0.548127         0.579559        0.039894
# 12           0.110099           0.105823         0.179737        0.101352
# 13           0.416890           0.399816         0.450940        0.060528
# 14           0.394224           0.394687         0.439498        0.063593
# 15           0.554602           0.548127         0.579559        0.039894
# 16           0.633662           0.608126         0.661057        0.057653
# 17           0.779390           0.752543         0.781298        0.024260
# 18           0.269267           0.323356         0.323072        0.043755
# 19           0.621636           0.621345         0.651037        0.041714
# 20           0.633160           0.607563         0.660834        0.058087
# 21           0.780583           0.753016         0.781368        0.023442
# 22           0.279335           0.394185         0.352361        0.051780
# 23           0.621636           0.621345         0.651037        0.041714
# 24           0.763675           0.723842         0.765505        0.034738
# 25           0.803686           0.773314         0.799868        0.020277
# 26          -0.181768          -0.080764        -0.105737        0.054749
# 27           0.622011           0.676058         0.669330        0.036157
# 28           0.763186           0.723346         0.765279        0.035073
# 29           0.803709           0.773491         0.799964        0.020235
# 30          -0.230672          -0.135219        -0.125605        0.089837
# 31           0.622011           0.676058         0.669330        0.036157
# 32           0.787582           0.761656         0.788715        0.022539
# 33           0.804323           0.775561         0.800758        0.019259
# 34          -1.129913          -0.830662        -0.972247        0.122627
# 35           0.625295           0.633109         0.656065        0.038060
# 36           0.787271           0.761361         0.788610        0.022782
# 37           0.804364           0.775659         0.800697        0.019099
# 38          -1.138305          -0.887159        -0.964699        0.122880
# 39           0.625295           0.633109         0.656065        0.038060
#
#     rank_test_score
# 0                35
# 1                32
# 2                33
# 3                27
# 4                36
# 5                31
# 6                34
# 7                27
# 8                29
# 9                22
# 10               24
# 11               19
# 12               30
# 13               21
# 14               23
# 15               19
# 16               13
# 17                8
# 18               26
# 19               17
# 20               14
# 21                7
# 22               25
# 23               17
# 24                9
# 25                4
# 26               37
# 27               11
# 28               10
# 29                3
# 30               38
# 31               11
# 32                5
# 33                1
# 34               40
# 35               15
# 36                6
# 37                2
# 38               39
# 39               15

# %%
#future prediction check with sample inputs
age_input=int(input("Enter the age input value:"))
bmi_input=int(input("Enter the age input value:"))
children_input=int(input("Enter the age input value:"))
sex_male_input=int(input("Enter the age input value:"))
smoker_yes_input=int(input("Enter the age input value:"))

# %%
Future_Prediction=regressor.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_Prediction={}".format(Future_Prediction))
