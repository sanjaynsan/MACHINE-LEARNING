# %%
#import all the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#pd is a class in which the function read_csv calls the excel
data = pd.read_csv('insurance_pre.csv')

# %%
#display the data
data.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
#Removing categorical data
data=pd.get_dummies(data,drop_first=True)

# %%
#refering the output and input to the variables independent and dependent
independent = data[["age","bmi","children","sex_male","smoker_yes"]]
dependent = data[['charges']]

# %%
#call traintest split fuction,assign the xtrain xtest ytrain ytest
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent,dependent,test_size = 1/3,random_state = 0)

# %%
#standarization or reparametrization for train set.this is makes the svm to pplot the points efficiently
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
#model creation calls LinearRegression fuction
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion':['mse','mae','friedman_mse'],'max_features':['auto', 'sqrt','log2'],'splitter':['best', 'random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True,verbose = 3,n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# C:\Users\sanjaykumar\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  54 | elapsed:    3.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    3.4s finished
# C:\Users\sanjaykumar\anaconda3\envs\AI\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#find y_pred using regressor.predict()
re=grid.cv_results_
grid_predictions = grid.predict(x_test)

# %%
#find r2score using r2_score()
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
#display r2 score
r_score
# Out:
# 0.6777621382650931

# %%
print("The r_square value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The r_square value for the best parameter{'criterion': 'mae', 'max_features': 'auto', 'splitter': 'best'}: 0.6777621382650931

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004053      0.002866         0.007397        0.003787
# 1        0.006746      0.004770         0.003382        0.004783
# 2        0.003367      0.004762         0.006077        0.004378
# 3        0.004732      0.003823         0.000000        0.000000
# 4        0.005419      0.003832         0.004743        0.003817
# 5        0.007460      0.003831         0.006742        0.004768
# 6        0.026228      0.004342         0.004029        0.004342
# 7        0.017478      0.003788         0.002678        0.003787
# 8        0.018805      0.000959         0.001356        0.000959
# 9        0.009389      0.000959         0.003370        0.003430
# 10       0.010109      0.000001         0.003354        0.003409
# 11       0.010072      0.000026         0.003349        0.003411
# 12       0.006026      0.004340         0.003349        0.003411
# 13       0.000673      0.000951         0.000000        0.000000
# 14       0.002677      0.003786         0.005354        0.003786
# 15       0.000000      0.000000         0.000000        0.000000
# 16       0.003334      0.004716         0.003334        0.004716
# 17       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.518085
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.633233
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.502720
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.525003
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.550139
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.479315
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.668411
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.642419
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.359884
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.669804
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.502476
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.653386
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.535034
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.687559
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.509772
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.611176
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.548219
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.337053
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.677321           0.686731         0.627257        0.077421
# 1            0.657202           0.664789         0.651720        0.013456
# 2            0.618126           0.688536         0.603015        0.076628
# 3            0.636081           0.568673         0.576528        0.045698
# 4            0.686517           0.642066         0.626156        0.056815
# 5            0.601109           0.608725         0.562956        0.059324
# 6            0.644973           0.675961         0.663121        0.013187
# 7            0.664734           0.679877         0.662321        0.015391
# 8            0.437855           0.433839         0.410469        0.035867
# 9            0.642083           0.605124         0.639038        0.026500
# 10           0.621288           0.664974         0.596141        0.068695
# 11           0.585780           0.603775         0.614357        0.028602
# 12           0.662707           0.686311         0.627913        0.066487
# 13           0.616241           0.651150         0.651690        0.029126
# 14           0.619544           0.669261         0.599425        0.066662
# 15           0.465127           0.643978         0.573469        0.077708
# 16           0.675500           0.691897         0.638437        0.064251
# 17           0.533365           0.590763         0.486892        0.108684
#
#     rank_test_score
# 0                 8
# 1                 3
# 2                11
# 3                14
# 4                 9
# 5                16
# 6                 1
# 7                 2
# 8                18
# 9                 5
# 10               13
# 11               10
# 12                7
# 13                4
# 14               12
# 15               15
# 16                6
# 17               17

# %%
#future prediction check with sample inputs
age_input=int(input("Enter the age input value:"))
bmi_input=int(input("Enter the age input value:"))
children_input=int(input("Enter the age input value:"))
sex_male_input=int(input("Enter the age input value:"))
smoker_yes_input=int(input("Enter the age input value:"))

# %%
Future_Prediction=regressor.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_Prediction={}".format(Future_Prediction))
